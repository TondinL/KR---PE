# %% [markdown]
# #Midnight mystery exam
# I will try to explore different approaches to try to extract from the dataset who the murder is, aggregating the resulting informations, the idea is to find it.

# %% [markdown]
# ---------------------------------------- <br>
# To start, I uploaded the JSON file to the drive, and from there I import it into the notebook.

# %%
import json

from google.colab import drive
drive.mount('/content/drive')


# path to the dataset on Google Drive
file_path = "/content/drive/MyDrive/murder_mystery_exam.json"

# function to load dataset
def load_dataset(path):
    try:
        with open(path, "r") as f:
            data = json.load(f)
        print("Dataset loaded")
        return data
    except Exception as e:
        print("Failed to load dataset:", e)
        return None

data = load_dataset(file_path)

if data:
    print("Case:", data["metadata"]["case_name"])
    print("Victim:", data["metadata"]["victim"])
    print("Interrogations:", len(data["interrogations"]))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset loaded
# Case: The Midnight Mystery
# Victim: Solicitor Gray
# Interrogations: 59

# %% [markdown]
# Then I install the openai API to work with the LLM model fro OpenRouter

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.82.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %% [markdown]
# My first idea, is to build two functions, that are based on LLM model, to extract two types of information from the interrogations: <br>
# - the self repoterd information ;
# - the informations about others contained inside each interrogation;
# <br><br> I try to output this informations in a "JSON" format, so to facilitate later manipulation.
#
# <br> I also extract location information, that can be then used to detect inconsistencies among interrogations

# %%
from openai import OpenAI

client = OpenAI(
    api_key="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",
    base_url="https://openrouter.ai/api/v1"
)

def extract_self_info(text, model="openai/gpt-4.1"):

    messages = [
        {"role": "system", "content": "You are an assistant that extracts structured information from witness statements. Respond only with a JSON object."},
        {"role": "user", "content": f"Extract the self-related information from this witness statement:\n\n'{text}'\n\nReturn a compact JSON object with the following keys: location, activity, time, emotion, and note_mention (True/False)."}
    ]

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        n=1,  # just to remember that can be modify (number of responses)

    )

    # Monitor token usage
    print("Prompt tokens:", response.usage.prompt_tokens)
    print("Completion tokens:", response.usage.completion_tokens)
    print("Total tokens:", response.usage.total_tokens)

    return response.choices[0].message.content # see total output for also token usage




def extract_other_info(text, model="openai/gpt-4-turbo"):

    # try to minimize token usage
    messages = messages = [
        {"role": "system", "content": "You are an assistant that extracts structured relational observations from witness statements."},
        {"role": "user", "content": f"""
        From the following witness statement:

        '{text}'

        Extract all mentions of other people seen by the speaker.
        For each person, return a dictionary with the keys: person_name, location, time, and interaction (True/False).
        Return a JSON list of these dictionaries. If nobody is mentioned, return an empty list: [].
        """}
    ]

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        n=1,  # just to remember that can be modify (number of responses)

    )

    # Monitor token usage
    print("Prompt tokens:", response.usage.prompt_tokens)
    print("Completion tokens:", response.usage.completion_tokens)
    print("Total tokens:", response.usage.total_tokens)

    return response.choices[0].message.content

# %% [markdown]
# For non wasting tokens, and to facilitate the usage of so extract data, i upload the results on a JSON file, that can be reused. <br> this code processes only not-processed guest, becouse some of them may result in error, with the need to run the code again to retry extracting their features.

# %%
import os
import time

# Path for the output file on google drive
output_path = "/content/drive/MyDrive/llm_extracted_info_exam.json"

# check if cached results already exist
if os.path.exists(output_path):
    print("JSON file already exists on drive")
    with open(output_path, "r") as f:
        all_results = json.load(f)
else:
    all_results = []

# list comprehension -> guest that where already processed
processed_guests = set([r["guest"] for r in all_results])

for entry in data["interrogations"]:
    guest = entry["guest"]
    statement = entry["statement"]

    # avoid token waste
    if guest in processed_guests:
        print(f"skipping {guest} (already processed)")
        continue

    print(f"analyzing: {guest}")

    try:
      self_info_raw = extract_self_info(statement)
      print("DEBUG self_info:", self_info_raw)
      self_info = json.loads(self_info_raw)

      other_info_raw = extract_other_info(statement)
      print("DEBUG other_info:", other_info_raw)
      other_info = json.loads(other_info_raw)
    except Exception as e:
        print(f"Failed to process {guest}: {e}")
        continue

    # save results
    result = {
        "guest": guest,
        "self_info": self_info,
        "others_info": other_info
    }
    all_results.append(result)

    # pause added to avoid hitting rate limits or overloading the API
    time.sleep(0.7)


with open(output_path, "w") as f:
    json.dump(all_results, f, indent=2)

print("results saved to:", output_path)
# Out:
# JSON file already exists on drive
# skipping Professor Blackstone (already processed)
# skipping Ambassador Indigo (already processed)
# skipping Baron Brown (already processed)
# skipping Mister Fitzgerald (already processed)
# skipping Commodore White (already processed)
# skipping Magistrate Ochre (already processed)
# skipping Doctor Scarlett (already processed)
# skipping Miss Azure (already processed)
# skipping Baron Blackwood (already processed)
# skipping Counselor Scarlett (already processed)
# skipping Rector Violet (already processed)
# skipping Barrister Beaumont (already processed)
# skipping Commodore Ebony (already processed)
# skipping Baron Sienna (already processed)
# skipping Magistrate Ruby (already processed)
# skipping Colonel Ravenswood (already processed)
# analyzing: Major Beaumont
# Prompt tokens: 473
# Completion tokens: 371
# Total tokens: 844
# DEBUG self_info: {
#   "location": "billiard room",
#   "activity": [
#     "talking with friends",
#     "discussing the evening's events with Miss Coral",
#     "enjoying the evening with Scarlett",
#     "in conversation with Viscountess White about business matters",
#     "talking with Ambassador Beaumont for quite some time",
#     "chatting with Chancellor Harrington",
#     "having a drink with Inspector Ivory",
#     "in conversation with Baron Whitehall about business matters",
#     "talking with Barrister Peacock for quite some time",
#     "enjoying the evening with Ruby",
#     "enjoying the evening with Duchess Cunningham",
#     "playing cards with Archbishop Coral",
#     "playing cards with Viscount Silver",
#     "in conversation with Inspector Ravenscroft about business matters",
#     "talking with Northbrook for quite some time",
#     "discussing the evening's events with Ambassador Indigo",
#     "enjoying the evening with Commodore White",
#     "enjoying the evening with Pearl",
#     "in conversation with Counselor Montgomery about business matters",
#     "having a drink with Dean Stonehaven",
#     "having a drink with Brigadier Black",
#     "chatting with Ochre",
#     "playing cards with Baron Blackwood",
#     "playing cards with Ravenswood",
#     "having a drink with Silver",
#     "enjoying the evening with Peacock",
#     "talking with General White for quite some time",
#     "talking with Major Whitmore for quite some time",
#     "chatting with Lady Crimson",
#     "chatting with Rector Sapphire",
#     "playing cards with Solicitor Sinclair"
#   ],
#   "time": "from about 11:30pm until well after midnight",
#   "emotion": "terrified",
#   "note_mention": true
# }
# Prompt tokens: 508
# Completion tokens: 1020
# Total tokens: 1528
# DEBUG other_info: [
#     {"person_name": "Miss Coral", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Scarlett", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Viscountess White", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Ambassador Beaumont", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Chancellor Harrington", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Inspector Ivory", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Baron Whitehall", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Barrister Peacock", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Ruby", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Duchess Cunningham", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Archbishop Coral", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Viscount Silver", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Inspector Ravenscroft", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Northbrook", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Ambassador Indigo", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Commodore White", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Pearl", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Counselor Montgomery", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Dean Stonehaven", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Brigadier Black", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Ochre", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Baron Blackwood", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Ravenswood", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Silver", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "General White", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Major Whitmore", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Lady Crimson", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Rector Sapphire", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True},
#     {"person_name": "Solicitor Sinclair", "location": "billiard room", "time": "11:30pm until after midnight", "interaction": True}
# ]
# Failed to process Major Beaumont: Expecting value: line 2 column 119 (char 120)
# skipping Earl Pearl (already processed)
# skipping Ambassador Gold (already processed)
# skipping Duchess Ravenswood (already processed)
# skipping Brigadier Black (already processed)
# skipping Miss Coral (already processed)
# skipping Mister Onyx (already processed)
# skipping Chancellor Harrington (already processed)
# skipping Countess Grimshaw (already processed)
# skipping Doctor Ashcroft (already processed)
# skipping Archbishop Whitmore (already processed)
# analyzing: Madame Northbrook
# Prompt tokens: 519
# Completion tokens: 50
# Total tokens: 569
# DEBUG self_info: {
#   "location": "conservatory",
#   "activity": "writing letters",
#   "time": "around 11:50pm",
#   "emotion": "surprised/confused",
#   "note_mention": true
# }
# Prompt tokens: 559
# Completion tokens: 1062
# Total tokens: 1621
# DEBUG other_info: [
#     {"person_name": "Commodore White", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Viscount Silver", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Magistrate Ochre", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Major Beaumont", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Ravenswood", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Rector Crimson", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Miss Coral", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Baron Blackwood", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Magistrate Ruby", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Count Silver", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Mister Coral", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Onyx", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Counselor Scarlett", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Ambassador Peacock", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Umber", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Stonehaven", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Black", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Counselor Montgomery", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Inspector Ravenscroft", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Baron Whitehall", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Inspector Ivory", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Chancellor Harrington", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Whitmore", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Earl Pearl", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Beaumont", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Duchess Cunningham", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Ambassador Indigo", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Archbishop Coral", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Peacock", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Ebony", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Doctor Scarlett", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Baron Nightingale", "location": "conservatory", "time": "11:50pm", "interaction": true},
#     {"person_name": "Solicitor Sinclair", "location": "conservatory", "time": "11:50pm", "interaction": true}
# ]
# skipping Viscountess White (already processed)
# skipping Rector Sapphire (already processed)
# skipping Solicitor Sinclair (already processed)
# skipping Viscount Pemberton (already processed)
# skipping Judge Winthrop (already processed)
# skipping Lord Green (already processed)
# skipping Baron Nightingale (already processed)
# skipping General White (already processed)
# skipping Baron Whitehall (already processed)
# skipping Mister Coral (already processed)
# skipping Ambassador Umber (already processed)
# skipping Solicitor Ravenscroft (already processed)
# skipping Viscount Silver (already processed)
# skipping Viscount Onyx (already processed)
# skipping Duchess Cunningham (already processed)
# skipping Ambassador Beaumont (already processed)
# skipping Barrister Peacock (already processed)
# skipping Counselor Montgomery (already processed)
# analyzing: Major Whitmore
# Prompt tokens: 480
# Completion tokens: 237
# Total tokens: 717
# DEBUG self_info: {"location":"gallery","activity":"resting, talking with Sienna, chatting with Counselor Montgomery, chatting with Viscount Onyx, enjoying the evening with Ambassador Umber, enjoying the evening with Ambassador Peacock, chatting with Earl Pearl, talking with Peacock, discussing evening's events with Brown, discussing evening's events with Indigo, discussing evening's events with Archbishop Coral, discussing evening's events with Magistrate Ochre, talking with Viscountess White, in conversation about business with Blackwood, in conversation about business with Madame Northbrook, in conversation about business with Chancellor Harrington, in conversation about business with Commodore White, in conversation about business with Miss Azure, enjoying the evening with Inspector Ravenscroft, enjoying the evening with Inspector Ivory, talking with Duchess Cunningham, talking with Brigadier Black, playing cards with Stonehaven, playing cards with Silver, playing cards with Ravenswood, playing cards with Crimson, playing cards with Count Silver, having a drink with Beaumont, having a drink with General White, having a drink with Mister Fitzgerald","time":"from about 11:30pm until well after midnight","emotion":"confused, unaware about the note","note_mention":true}
# Prompt tokens: 516
# Completion tokens: 1050
# Total tokens: 1566
# DEBUG other_info: ```json
# [
#     {"person_name": "Brown", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Ambassador Umber", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Sienna", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Counselor Montgomery", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Viscount Onyx", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Ambassador Peacock", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Earl Pearl", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Peacock", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Blackwood", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Inspector Ravenscroft", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Stonehaven", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Beaumont", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Madame Northbrook", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Silver", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Chancellor Harrington", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Indigo", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Commodore White", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "General White", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Archbishop Coral", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Magistrate Ochre", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Viscountess White", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Ravenswood", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Crimson", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Inspector Ivory", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Duchess Cunningham", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Count Silver", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Brigadier Black", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Miss Azure", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true},
#     {"person_name": "Mister Fitzgerald", "location": "gallery", "time": "about 11:30pm until well after midnight", "interaction": true}
# ]
# ```
# Failed to process Major Whitmore: Expecting value: line 1 column 1 (char 0)
# skipping Count Silver (already processed)
# skipping Archbishop Coral (already processed)
# skipping Ambassador Northbrook (already processed)
# skipping Solicitor Beaumont (already processed)
# analyzing: Rector Crimson
# Prompt tokens: 497
# Completion tokens: 63
# Total tokens: 560
# DEBUG self_info: {
#   "location": "attic",
#   "activity": "smoking a pipe, relaxing, talking with others, discussing events, playing cards, having drinks",
#   "time": "late in the evening",
#   "emotion": "relaxed, confused",
#   "note_mention": true
# }
# Prompt tokens: 538
# Completion tokens: 1215
# Total tokens: 1753
# DEBUG other_info: [
#     {
#         "person_name": "Ochre",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Baron Blackwood",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Barrister Peacock",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Duchess Ravenswood",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "White",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Inspector Ivory",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Duchess Cunningham",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Viscount Silver",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Counselor Scarlett",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Indigo",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Peacock",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Mister Coral",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Counselor Montgomery",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Chancellor Harrington",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Baron Brown",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Major Whitmore",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Ruby",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Inspector Ravenscroft",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Count Silver",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Baron Sienna",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Major Beaumont",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Ambassador Beaumont",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Black",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "General White",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Archbishop Coral",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Umber",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Pearl",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Doctor Scarlett",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Doctor Grimshaw",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Rector Violet",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Beaumont",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": true
#     },
#     {
#         "person_name": "Doctor Ashcroft",
#         "location": "attic",
#         "time": "late in the evening",
#         "interaction": false
#     }
# ]
# skipping Inspector Ravenscroft (already processed)
# skipping Lady Crimson (already processed)
# skipping Doctor Grimshaw (already processed)
# skipping Inspector Ivory (already processed)
# analyzing: Ambassador Peacock
# Prompt tokens: 502
# Completion tokens: 62
# Total tokens: 564
# DEBUG self_info: {
#   "location": "conservatory",
#   "activity": "playing cards, chatting with various people, having drinks, discussing business matters, discussing evening's events",
#   "time": "just before midnight",
#   "emotion": "surprised",
#   "note_mention": true
# }
# Prompt tokens: 543
# Completion tokens: 1003
# Total tokens: 1546
# DEBUG other_info: [
#     {"person_name": "Ambassador Umber", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Onyx", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Peacock", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Blackwood", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Ambassador Beaumont", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Duchess Ravenswood", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "White", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Ochre", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Earl Pearl", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Ruby", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Chancellor Harrington", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Inspector Ravenscroft", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Colonel Ravenswood", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Ivory", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Duchess Cunningham", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Rector Crimson", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Silver", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Baron Brown", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Counselor Montgomery", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Baron Sienna", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Beaumont", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Coral", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Major Whitmore", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Commodore White", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Counselor Scarlett", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Dean Stonehaven", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Northbrook", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Solicitor Ravenscroft", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Solicitor Beaumont", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Baron Nightingale", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Duchess Summerville", "location": "conservatory", "time": "just before midnight", "interaction": True},
#     {"person_name": "Whitmore", "location": "conservatory", "time": "just before midnight", "interaction": True}
# ]
# Failed to process Ambassador Peacock: Expecting value: line 2 column 116 (char 117)
# skipping Duchess Summerville (already processed)
# skipping Dean Stonehaven (already processed)
# results saved to: /content/drive/MyDrive/llm_extracted_info_exam.json

# %% [markdown]
# One problem that emerges from this approach is that the execution time of the last cell is really slow, with some of the guest that fail to process ( and given the large amout of guests, a large token usage ).
#
# I will try to execute the cell another time ( after the first, where a good percentage of guests failed to process, to see if this resolves ) -> from this re-execute approach I was able to find the information even of the guests I had failed to process. After the third execution there are still 3 that failed to process.
#
# I try anyway to procced with this pipeline: <br>

# %% [markdown]
# <br>I try to build from the JSON file that I so created a dataframe using pandas, to facilitate further analysis. <br> I will create three tables, one for the self info, one for the others info, and one with the aggregated informations.

# %%
import pandas as pd

with open("/content/drive/MyDrive/llm_extracted_info_exam.json", "r") as f:
    all_results = json.load(f)

# build a DataFrame with the self-related information

self_rows = []
for entry in all_results:
    guest = entry.get("guest")
    self_info = entry.get("self_info", {})

    self_rows.append({
        "guest": guest,
        "location": self_info.get("location"),
        "activity": self_info.get("activity"),
        "time": self_info.get("time"),
        "emotion": self_info.get("emotion"),
        "note_mention": self_info.get("note_mention")
    })

df_self = pd.DataFrame(self_rows)

# %% [markdown]
# visualizing the resulting dataframe:

# %%
print(df_self.columns)
df_self.info()
df_self.head()
# Out:
# Index(['guest', 'location', 'activity', 'time', 'emotion', 'note_mention'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   guest         56 non-null     object
#  1   location      56 non-null     object
#  2   activity      56 non-null     object
#  3   time          56 non-null     object
#  4   emotion       54 non-null     object
#  5   note_mention  56 non-null     bool
# dtypes: bool(1), object(5)
# memory usage: 2.4+ KB
#                guest      location  \
# 0  Ambassador Indigo  conservatory
# 1        Baron Brown         study
# 2   Magistrate Ochre        garden
# 3    Doctor Scarlett       kitchen
# 4         Miss Azure       kitchen
#
#                                             activity  \
# 0  listening to music, discussing events and busi...
# 1  [having a drink, playing cards, chatting, talk...
# 2  [having a drink, chatting, conversation about ...
# 3  [writing letters, relaxing, talking with Count...
# 4  smoking a pipe, having drinks, discussing even...
#
#                                            time  \
# 0  from about 11:30pm until well after midnight
# 1  from about 11:30pm until well after midnight
# 2                                      evenings
# 3                                       11:50pm
# 4                                around 11:50pm
#
#                                              emotion  note_mention
# 0  confused (couldn't understand why when I heard...         False
# 1                                            shocked          True
# 2  [routine, unable to process what happened, sur...          True
# 3                                           confused          True
# 4                                 surprise/disbelief          True

# %%
others_rows = []

for entry in all_results:
    observer = entry.get("guest")
    for obs in entry.get("others_info", []):
        others_rows.append({
            "observer": observer,
            "person_seen": obs.get("person_name"),
            "location": obs.get("location"),
            "time": obs.get("time"),
            "interaction": obs.get("interaction")
        })

df_others = pd.DataFrame(others_rows)

# %% [markdown]
# visualizing the resulting dataframe:

# %%
print(df_others.columns)

df_others.head()
# Out:
# Index(['observer', 'person_seen', 'location', 'time', 'interaction'], dtype='object')
#             observer       person_seen      location  \
# 0  Ambassador Indigo   Magistrate Ruby  conservatory
# 1  Ambassador Indigo         Blackwood  conservatory
# 2  Ambassador Indigo             Brown  conservatory
# 3  Ambassador Indigo  Magistrate Ochre  conservatory
# 4  Ambassador Indigo           Crimson  conservatory
#
#                                 time  interaction
# 0  11:30pm until well after midnight         True
# 1  11:30pm until well after midnight         True
# 2  11:30pm until well after midnight         True
# 3  11:30pm until well after midnight         True
# 4  11:30pm until well after midnight         True

# %% [markdown]
# Aggregate the informations to one single dataframe:

# %%
# merge the two DataFrames for combined analysis
df_merged = df_others.merge(df_self, left_on="observer", right_on="guest", suffixes=("_seen", "_self"))

df_merged.head()
# Out:
#             observer       person_seen location_seen  \
# 0  Ambassador Indigo   Magistrate Ruby  conservatory
# 1  Ambassador Indigo         Blackwood  conservatory
# 2  Ambassador Indigo             Brown  conservatory
# 3  Ambassador Indigo  Magistrate Ochre  conservatory
# 4  Ambassador Indigo           Crimson  conservatory
#
#                            time_seen  interaction              guest  \
# 0  11:30pm until well after midnight         True  Ambassador Indigo
# 1  11:30pm until well after midnight         True  Ambassador Indigo
# 2  11:30pm until well after midnight         True  Ambassador Indigo
# 3  11:30pm until well after midnight         True  Ambassador Indigo
# 4  11:30pm until well after midnight         True  Ambassador Indigo
#
#   location_self                                           activity  \
# 0  conservatory  listening to music, discussing events and busi...
# 1  conservatory  listening to music, discussing events and busi...
# 2  conservatory  listening to music, discussing events and busi...
# 3  conservatory  listening to music, discussing events and busi...
# 4  conservatory  listening to music, discussing events and busi...
#
#                                       time_self  \
# 0  from about 11:30pm until well after midnight
# 1  from about 11:30pm until well after midnight
# 2  from about 11:30pm until well after midnight
# 3  from about 11:30pm until well after midnight
# 4  from about 11:30pm until well after midnight
#
#                                              emotion  note_mention
# 0  confused (couldn't understand why when I heard...         False
# 1  confused (couldn't understand why when I heard...         False
# 2  confused (couldn't understand why when I heard...         False
# 3  confused (couldn't understand why when I heard...         False
# 4  confused (couldn't understand why when I heard...         False

# %%
df_merged.describe(percentiles=[])
# Out:
#                  observer person_seen location_seen time_seen interaction  \
# count                1427        1427          1395      1395        1427
# unique                 54         101            15        12           2
# top     Ambassador Indigo  Ravenswood       kitchen   11:50pm        True
# freq                   35          26           152       503        1419
#
#                     guest location_self  \
# count                1427          1427
# unique                 54            15
# top     Ambassador Indigo       kitchen
# freq                   35           152
#
#                                                  activity time_self  emotion  \
# count                                                1427      1427     1372
# unique                                                 54        14       29
# top     listening to music, discussing events and busi...   11:50pm  worried
# freq                                                   35       363      161
#
#        note_mention
# count          1427
# unique            2
# top            True
# freq           1195

# %% [markdown]
# From the df, we try to see if there is some guest that has not been seen by anyone, which would make him a suspect:

# %%
all = set(df_others["observer"]).union(set(df_others["person_seen"]))

seen = set(df_others["person_seen"])

not_seen = all - seen

print("guests not seen by anyone:")
print(not_seen)
# Out:
# guests not seen by anyone:
# set()

# %% [markdown]
# There is no guest that was not seen from anyone in general, we need to filter this observation restricted to the time of the murder:

# %%
# see what values are there for the time
print(df_others["time"].unique())
# Out:
# ['11:30pm until well after midnight' 'evening' '11:50pm' None
#  '11:30pm until after midnight' 'late in the evening' 'evenings'
#  'before midnight' 'unspecified' 'when the clock struck twelve'
#  '11:30pm to after midnight'
#  'from about 11:30pm until well after midnight' 'just before midnight']

# %% [markdown]
# All time references refer to the time of the murder, exept for 'unspecified'

# %%
df_others[df_others["time"].str.contains("unspecified", case=False, na=False)]
# Out:
#          observer        person_seen location         time  interaction
# 212  Baron Sienna       Count Silver   cellar  unspecified         True
# 213  Baron Sienna          Blackwood   cellar  unspecified         True
# 214  Baron Sienna              Ivory   cellar  unspecified         True
# 215  Baron Sienna         Northbrook   cellar  unspecified         True
# 216  Baron Sienna            Peacock   cellar  unspecified         True
# 217  Baron Sienna    Dean Stonehaven   cellar  unspecified         True
# 218  Baron Sienna           Beaumont   cellar  unspecified         True
# 220  Baron Sienna         Ravenswood   cellar  unspecified         True
# 221  Baron Sienna    Magistrate Ruby   cellar  unspecified         True
# 222  Baron Sienna   Archbishop Coral   cellar  unspecified         True
# 223  Baron Sienna    Viscount Silver   cellar  unspecified         True
# 226  Baron Sienna         Harrington   cellar  unspecified         True
# 228  Baron Sienna              White   cellar  unspecified         True
# 229  Baron Sienna     Major Whitmore   cellar  unspecified         True
# 230  Baron Sienna     Rector Crimson   cellar  unspecified         True
# 231  Baron Sienna   Magistrate Ochre   cellar  unspecified         True
# 232  Baron Sienna  Ambassador Indigo   cellar  unspecified         True
# 233  Baron Sienna   Ambassador Umber   cellar  unspecified         True
# 234  Baron Sienna         Earl Pearl   cellar  unspecified         True
# 236  Baron Sienna        Ravenscroft   cellar  unspecified         True
# 237  Baron Sienna               Gold   cellar  unspecified         True
# 239  Baron Sienna      Rector Violet   cellar  unspecified         True
# 240  Baron Sienna        Mister Onyx   cellar  unspecified         True
# 242  Baron Sienna    Doctor Ashcroft   cellar  unspecified        False

# %% [markdown]
# An other direction that I have not had time to explore is modeling guest relations in the form of a directed graph, starting from the df, in which nodes represent characters and arcs indicate who saw whom. This graph could have been analyzed to detect anomalous behavior, isolated guests, or used in conjunction with graph neural networks (GNN) techniques to infer suspects based on social structure and statements.

# %% [markdown]
# -------------------------------------

# %% [markdown]
# The next step  that I try, is to compare the victim's text with that of the suspects, to measure the similarity between the victim_note and the interrogations, to identify semantic correspondences, such as consistent events, commonplaces, overlapping tenses or narrative contradictions. <br>
# As a model, I used all-mpnet-base-v2 based on bert:

# %%
# %pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.32.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 859.9 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from sentence_transformers import SentenceTransformer, util

# load model
model = SentenceTransformer("all-mpnet-base-v2")

victim_note = data["metadata"]["victim_note"]

interrogations = [(entry["guest"], entry["statement"]) for entry in data["interrogations"]]

# encode victim note
victim_embedding = model.encode(victim_note, convert_to_tensor=True)

# encode each interrogation and calculate cosine similarity
results = []
for guest, statement in interrogations:
    statement_embedding = model.encode(statement, convert_to_tensor=True)
    similarity = util.cos_sim(victim_embedding, statement_embedding).item()
    results.append((guest, similarity))

# sort by similarity descending
results.sort(key=lambda x: x[1], reverse=True)

for guest, score in results[:10]:
    print(f"{guest}: {score:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Viscount Pemberton: 0.4467
# Baron Sienna: 0.4099
# Chancellor Harrington: 0.3936
# Duchess Ravenswood: 0.3828
# Dean Stonehaven: 0.3824
# Baron Whitehall: 0.3816
# Magistrate Ruby: 0.3814
# Baron Brown: 0.3776
# Countess Grimshaw: 0.3744
# Magistrate Ochre: 0.3683

# %% [markdown]
# From this approach, there are some Guests that appear to be "similar" in therm of semantic to the letter of the victim. We can keep the top 5 as possible suspects.

# %% [markdown]
# One possible approach is to apply embeddings on the interrogations, and from this to aplly clustering. <br> The idea is to use DBSCAN as a clustering method to detect possible outliers. <br>
# That is done, with the idea that the semantical difference from the outlier means that he mention about thing that are not mentioned by others, narrating about something that is unique and that his story does not match with the "story patterns" of the other guests

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt


statements = [entry["statement"] for entry in data["interrogations"]]
guests = [entry["guest"] for entry in data["interrogations"]]

# compute the embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(statements)

# clustering with DBSCAN
db = DBSCAN(eps=0.4, min_samples=2, metric='cosine').fit(embeddings)
labels = db.labels_

for guest, label in zip(guests, labels):
    print(f"{guest}: cluster {label}")

# identification of outliers
outliers = [guests[i] for i, label in enumerate(labels) if label == -1]
print("\nOutlier (semantically distant):", outliers)
# Out:
# Professor Blackstone: cluster 0
# Ambassador Indigo: cluster 0
# Baron Brown: cluster 0
# Mister Fitzgerald: cluster 0
# Commodore White: cluster 0
# Magistrate Ochre: cluster 0
# Doctor Scarlett: cluster 0
# Miss Azure: cluster 0
# Baron Blackwood: cluster 0
# Counselor Scarlett: cluster 0
# Rector Violet: cluster 0
# Barrister Beaumont: cluster 0
# Commodore Ebony: cluster 0
# Baron Sienna: cluster 0
# Magistrate Ruby: cluster 0
# Colonel Ravenswood: cluster 0
# Major Beaumont: cluster 0
# Earl Pearl: cluster 0
# Ambassador Gold: cluster 0
# Duchess Ravenswood: cluster 0
# Brigadier Black: cluster 0
# Miss Coral: cluster 0
# Mister Onyx: cluster 0
# Chancellor Harrington: cluster 0
# Countess Grimshaw: cluster 0
# Doctor Ashcroft: cluster -1
# Archbishop Whitmore: cluster 0
# Madame Northbrook: cluster 0
# Viscountess White: cluster 0
# Rector Sapphire: cluster 0
# Solicitor Sinclair: cluster 0
# Viscount Pemberton: cluster 0
# Judge Winthrop: cluster 0
# Lord Green: cluster 0
# Baron Nightingale: cluster 0
# General White: cluster 0
# Baron Whitehall: cluster 0
# Mister Coral: cluster 0
# Ambassador Umber: cluster 0
# Solicitor Ravenscroft: cluster 0
# Viscount Silver: cluster 0
# Viscount Onyx: cluster 0
# Duchess Cunningham: cluster 0
# Ambassador Beaumont: cluster 0
# Barrister Peacock: cluster 0
# Counselor Montgomery: cluster 0
# Major Whitmore: cluster 0
# Count Silver: cluster 0
# Archbishop Coral: cluster 0
# Ambassador Northbrook: cluster 0
# Solicitor Beaumont: cluster 0
# Rector Crimson: cluster 0
# Inspector Ravenscroft: cluster 0
# Lady Crimson: cluster 0
# Doctor Grimshaw: cluster 0
# Inspector Ivory: cluster 0
# Ambassador Peacock: cluster 0
# Duchess Summerville: cluster 0
# Dean Stonehaven: cluster 0
#
# Outlier (semantically distant): ['Doctor Ashcroft']

# %% [markdown]
# From the first execution with eps parameter =1 , there where no outlieres identified (and all guests where assigned to cluster 0), I will try to execute it another time with a stricter value (0.4) -> with this stricter value HDSCAN identifies Doctor Ashcroft as a outlier, we can ad him to the suspects
#
# <br> <br>

# %% [markdown]
# From that i try also to compute the guest with the highest distance (cosine distance) in the embedding space ( that should be pointed as outlier with the DBSCAN method )

# %%
from sklearn.metrics.pairwise import cosine_distances

distance_matrix = cosine_distances(embeddings)

# average distance for each witness (ignoring self)
avg_distances = distance_matrix.mean(axis=1)

guest_names = [entry["guest"] for entry in all_results]
# identification of the most distant witness (semantic outlier)
most_distant_idx = np.argmax(avg_distances)
most_distant_guest = guest_names[most_distant_idx]
most_distant_value = avg_distances[most_distant_idx]

print(f"The most semantically distant guest is: {most_distant_guest} (average distance: {most_distant_value:.4f})")
# Out:
# The most semantically distant guest is: Mister Coral (average distance: 0.4665)

# %% [markdown]
# The most semantically distant guest is Mister Coral, we can add him to the suspect list.

# %% [markdown]
# I try to do the same but insted of using the pretrained SBERT model, I try to use the model that I used to measure the similarity between victim_note and interrogations, to see if and how much the results change.

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt


statements = [entry["statement"] for entry in data["interrogations"]]
guests = [entry["guest"] for entry in data["interrogations"]]

# compute the embeddings
model = SentenceTransformer("all-mpnet-base-v2")
embeddings = model.encode(statements)

# clustering with DBSCAN
db = DBSCAN(eps=0.4, min_samples=2, metric='cosine').fit(embeddings)
labels = db.labels_

for guest, label in zip(guests, labels):
    print(f"{guest}: cluster {label}")

# identification of outliers
outliers = [guests[i] for i, label in enumerate(labels) if label == -1]
print("\nOutlier (semantically distant):", outliers)
# Out:
# Professor Blackstone: cluster 0
# Ambassador Indigo: cluster 0
# Baron Brown: cluster 0
# Mister Fitzgerald: cluster 0
# Commodore White: cluster 0
# Magistrate Ochre: cluster 0
# Doctor Scarlett: cluster 0
# Miss Azure: cluster 0
# Baron Blackwood: cluster 0
# Counselor Scarlett: cluster 0
# Rector Violet: cluster 0
# Barrister Beaumont: cluster 0
# Commodore Ebony: cluster 0
# Baron Sienna: cluster 0
# Magistrate Ruby: cluster 0
# Colonel Ravenswood: cluster 0
# Major Beaumont: cluster 0
# Earl Pearl: cluster 0
# Ambassador Gold: cluster 0
# Duchess Ravenswood: cluster 0
# Brigadier Black: cluster 0
# Miss Coral: cluster 0
# Mister Onyx: cluster 0
# Chancellor Harrington: cluster 0
# Countess Grimshaw: cluster 0
# Doctor Ashcroft: cluster 0
# Archbishop Whitmore: cluster 0
# Madame Northbrook: cluster 0
# Viscountess White: cluster 0
# Rector Sapphire: cluster 0
# Solicitor Sinclair: cluster 0
# Viscount Pemberton: cluster 0
# Judge Winthrop: cluster 0
# Lord Green: cluster 0
# Baron Nightingale: cluster 0
# General White: cluster 0
# Baron Whitehall: cluster 0
# Mister Coral: cluster 0
# Ambassador Umber: cluster 0
# Solicitor Ravenscroft: cluster 0
# Viscount Silver: cluster 0
# Viscount Onyx: cluster 0
# Duchess Cunningham: cluster 0
# Ambassador Beaumont: cluster 0
# Barrister Peacock: cluster 0
# Counselor Montgomery: cluster 0
# Major Whitmore: cluster 0
# Count Silver: cluster 0
# Archbishop Coral: cluster 0
# Ambassador Northbrook: cluster 0
# Solicitor Beaumont: cluster 0
# Rector Crimson: cluster 0
# Inspector Ravenscroft: cluster 0
# Lady Crimson: cluster 0
# Doctor Grimshaw: cluster 0
# Inspector Ivory: cluster 0
# Ambassador Peacock: cluster 0
# Duchess Summerville: cluster 0
# Dean Stonehaven: cluster 0
#
# Outlier (semantically distant): []

# %% [markdown]
# With this other embeddings, we have no outliers, and all guests are assigned to same cluster, with an eps of 0.4.

# %%
from sklearn.metrics.pairwise import cosine_distances

distance_matrix = cosine_distances(embeddings)

# average distance for each witness (ignoring self)
avg_distances = distance_matrix.mean(axis=1)

guest_names = [entry["guest"] for entry in all_results]
# identification of the most distant witness (semantic outlier)
most_distant_idx = np.argmax(avg_distances)
most_distant_guest = guest_names[most_distant_idx]
most_distant_value = avg_distances[most_distant_idx]

print(f"The most semantically distant guest is: {most_distant_guest} (average distance: {most_distant_value:.4f})")
# Out:
# The most semantically distant guest is: Mister Coral (average distance: 0.4665)

# %% [markdown]
# Here we also have as output Mr. Coral.

# %% [markdown]
# Always focusing on the writing style of the guests, I try to ask the LLM what I tried to compute using embeddings. That is, to return the more similar guest in term of writing style with the letter.

# %%
def extract_self_info(text, model="openai/gpt-4.1"):

    messages = [
        {"role": "system", "content": "You are an linguistic expert that compares writing styles and returns a score of similarity."},
        {"role": "user", "content": f"This is the text referencet:\n\n'{text}'\n\ compare it whit this textt:\n\n'{text}'\n\ and return a score similarity from 0 to 10 considering the style and tone "}
    ]

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        n=1,  # just to remember that can be modify (number of responses)

    )

    # Monitor token usage
    print("Prompt tokens:", response.usage.prompt_tokens)
    print("Completion tokens:", response.usage.completion_tokens)
    print("Total tokens:", response.usage.total_tokens)

    return response.choices[0].message.content # see total output for also token usage
